# %%
import pandas as pd

data = [['Chips:','Simba',14,10,300,'Lays',15,16,300,'Doritos',15,18,300],['Cooldrinks:','Coke',12,25,300,'Fanta',16,12,350,'Sprite',18,30,400],
       ['Chocolates:','Cadbury',14,20,400,'tex',9,10,350,'PS',10,25,370],['Pies:','Pepper Steak',18,10,250,'Chicken',20,15,235,'Steak and Kidney',22,20,300],
       ['Fruit:','Pear',3,10,70,'Apple',2.50,17,85,'Orange',3,35,100],['Cupcakes:','vanilla',7,12,100,'chocolate',5,20,120,'Bran',5,15,130],
       ['Vegies:','spinach',8,10,160,'cabbage',10,15,200,'Potatoes',6,15,350]]
df = pd.DataFrame(data,columns=['Catergory','1st Brand','Price in Rands','Quantity1','Stock Price(R)','2nd Brand','Price in Rands','Quantity2','Stock Price(R)','3rd Brand','Prices in Rands','Quantity3','Stock Price(R)'],index=['a','b','c','d','e','f','g'])

# %%
df
# Out:
#      Catergory     1st Brand  Price in Rands  Quantity1  Stock Price(R)  \
# a       Chips:         Simba              14         10             300
# b  Cooldrinks:          Coke              12         25             300
# c  Chocolates:       Cadbury              14         20             400
# d        Pies:  Pepper Steak              18         10             250
# e       Fruit:          Pear               3         10              70
# f    Cupcakes:       vanilla               7         12             100
# g      Vegies:       spinach               8         10             160
#
#    2nd Brand  Price in Rands  Quantity2  Stock Price(R)         3rd Brand  \
# a       Lays            15.0         16             300           Doritos
# b      Fanta            16.0         12             350            Sprite
# c        tex             9.0         10             350                PS
# d    Chicken            20.0         15             235  Steak and Kidney
# ...

# %%
df.plot(x='Catergory', y='Quantity1', kind='line')

# %%
df.plot(x='Catergory', y='Quantity2', kind='line')

# %%
df.plot(x='Catergory', y='Quantity3', kind='line')
