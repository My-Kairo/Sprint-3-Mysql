# %%
import pandas as pd

df = pd.read_csv('SQLDATA.csv', sep=';')

# %%
df
# Out:
#      Food Type                 Items   Size Selling Price(R) Quantity  \
# 0        Chips                 Simba   125g               14       15
# 1        Chips                  Lays   125g               15       10
# 2        Chips               Doritos   125g               16       12
# 3        Chips            Nick Nacks    50g                1       40
# 4        Chips                 Bigga    50g                1       50
# 5        Chips        Crack-A-Snacks    50g                1       50
# 6    CoolDrink                  Coke    2lt               18       22
# 7    Cooldrink            Fanta Pine    2lt               17       25
# 8    Cooldrink          Fanta Orange    2lt               16       23
# 9    Cooldrink      Granadilla Twist    2lt               20       20
# 10   Cooldrink           Lemon Twist    2lt               18       25
# 11  Cooldrinks                Shweps    2lt               20       25
# ...

# %%
import mysql.connector
mydb = mysql.connector.connect(host="localhost", user="root", passwd="Thatoaka1")
mycursor = mydb.cursor()
mycursor.execute("SHOW DATABASES")

for x in mycursor:
    print(x)
# Out:
# ('information_schema',)
# ('mydatabase',)
# ('mysql',)
# ('performance_schema',)
# ('sqldata',)
# ('sys',)

# %%
pip install sqlalchemy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pymysql
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import sqlalchemy
import pymysql
#from scipy import stats

engine=sqlalchemy.create_engine("mysql+pymysql://root:Thatoaka1@localhost/sqldata")
df=pd.read_sql_table('sqldata', engine)

#ALTER.TABLE(vendors)
#ADD[COLUMN] 'Sales_per_day' INT, AFTER Profit(R);
#df = pd.DataFrame({'Sales': [8,7,8,30,35,17,18,15,12,13,16,17,13,10,12,11,10,16,14,14,23,20,21,
                    #60,69,55,50,63,75,36,29,31,31,45,19,17,19,25,33,30,29,21,12,20,19,17,38,22,20]})

# %%
import sqlite3
import mysql.connector
#import mySQLdb as sql
import pymysql

#connection = self.connect()
mydb = mysql.connector.connect(host="localhost", user="root", passwd="Thatoaka1", database="sqldata")
cursor=mydb.cursor()
cursor.execute("ALTER TABLE sqldata ADD Shelve_No VARCHAR(50) NOT NULL")
#sql="INSERT INTO 'sqldata'(Sales),VALUES(%s
#cursor.execute()
#mydb.commit()
#sql="SELECT * FROM 'sqldata'"
#cursor.execute(sql)
#result = cursor.fetchall()
#for d in result:
 #   print(d)
#except for Error as e:
 #   print(e)
#finally:
mydb.close()
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\mysql\connector\connection_cext.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     488                                raw=raw, buffered=buffered,
# --> 489                                raw_as_string=raw_as_string)
#     490         except MySQLInterfaceError as exc:
#
# MySQLInterfaceError: Duplicate column name 'Shelve_No'
#
# During handling of the above exception, another exception occurred:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-2-77b2fbe70723> in <module>
#       7 mydb = mysql.connector.connect(host="localhost", user="root", passwd="Thatoaka1", database="sqldata")
#       8 cursor=mydb.cursor()
# ----> 9 cursor.execute("ALTER TABLE sqldata ADD Shelve_No VARCHAR(50) NOT NULL")
# ...

# %%
df
# Out:
#      Food Type                 Items   Size  Selling Price(R)  Quantity  \
# 0        Chips                 Simba   125g                14        15
# 1        Chips                  Lays   125g                15        10
# 2        Chips               Doritos   125g                16        12
# 3        Chips            Nick Nacks    50g                 1        40
# 4        Chips                 Bigga    50g                 1        50
# 5        Chips        Crack-A-Snacks    50g                 1        50
# 6    CoolDrink                  Coke    2lt                18        22
# 7    Cooldrink            Fanta Pine    2lt                17        25
# 8    Cooldrink          Fanta Orange    2lt                16        23
# 9    Cooldrink      Granadilla Twist    2lt                20        20
# 10   Cooldrink           Lemon Twist    2lt                18        25
# 11  Cooldrinks                Shweps    2lt                20        25
# ...

# %%
df['Sales per_week'] = df['Profit(R)']- df['Stock price(R)']

#ALTER.TABLE(sqldata)
#ADD('Sales per week' VARCHAR(5) NOT NULL DEFAULT 1
#AFTER Profit(R);
#SET
 #  SELECT COLUMN_NAME
#FROM
    #information_schema.columns
#WHERE
    #table_schema = 'database_name' AND TABLE_NAME = 'table_name' AND ordinal_position = 56
#);
#SET
 #   @query = CONCAT(
  #      'ALTER TABLE `table_name` ADD `new_column_name` int(5) AFTER ',
  #      @column_name
#    );
#PREPARE
 #   stmt
#FROM
#    @query;
#EXECUTE
 #   stmt;
#DEALLOCATE
 #   stmt;

# %%
x=df['Food Type']
y=df['Stock price(R)']

fig = plt.figure(figsize=(15,10))
plt.bar(x, y)
plt.title('Bar graph', size=20)
plt.xlabel('Food Type', size=20)
plt.ylabel('Stock Price', size=20)

plt.show()

# %%
x=df['Items']
y=df['Quantity']

fig = plt.figure(figsize=(15,10))
plt.xticks(rotation=90)

plt.scatter(x, y, c='g')
plt.title('Scatter plot', size=20)
plt.xlabel('Items', size=20)
plt.ylabel('Quantity', size=20)

plt.show()

# %%
x=df['Selling Price(R)']
y=df['Profit(R)']
#y1=df['Profit(R)']

fig = plt.figure(figsize=(15,10))
plt.scatter(x,y)
plt.title('Scatter Plot', size=20)
plt.xlabel('Selling Price', size=20)
plt.ylabel('Profit', size=20)
# Out:
# Text(0, 0.5, 'Profit')

# %%
#y=df['Food Type']
x=df['Profit(R)']
y1=df['Stock price(R)']

#fig = plt.figure(figsize=(15,10))
plt.scatter(x,y1)
plt.xlabel('Profit')
plt.ylabel('Stock price(R)')
plt.show()

# %%
x=df['Items']
y=df['Quantity']
#y1=df['Stock price(R)']

fig = plt.figure(figsize=(30,10))
plt.xticks(rotation=60)
plt.plot(x,y,'rx-', label = 'Items')
#plt.plot(x,y1,'b*-', label = 'Profit(R)')
plt.xlabel('Items', size=40)
plt.ylabel('Profit', size=40)
plt.title('Line Graph of items vs profit', size=50)
plt.legend()
plt.show()
#plt.plot(y, 'r*')
#plt.plot(y1, 'bx--')

# %%
#x=df['Food Type']
y=df['Quantity']
y1=df['Profit(R)']
#y1=df['Profit(R)']

fig = plt.figure(figsize=(15,10))
plt.plot(y,'bo-')
plt.plot(y1,'g*--')
plt.title('Scatter Plot', size=20)
plt.xlabel('Quantity', size=20)
plt.ylabel('Profit', size=20)
plt.show()
#plt.plot(y, 'r*')
#plt.plot(y1, 'bx--')

# %%
#y=df['Food Type']
#x=df['Profit(R)']
y1=df['Stock price(R)']

#fig = plt.figure(figsize=(15,10))
plt.hist(y1, color='yellow', histtype='step')
plt.xlabel('Bins')
plt.ylabel('Frequency')
plt.title('Histogram', size=20)
plt.show()
#plt.plot(y, 'r*')
#plt.plot(y1, 'bx--')

# %%
y1=df['Stock price(R)']

plt.hist(df['Profit(R)'])
plt.xlabel('Bins')
plt.ylabel('Frequency')
plt.title('Histogram', size=20)
plt.show()

# %%
x=['Selling price(R)']
y=['Profit(R)']

slope,interception,r,std_err = stats.linregress(x,y)
def fn(x):
    return slope * x + intercept
speed=fn(5)
print(speed)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-1c8655c6cd36> in <module>
#       2 y=['Profit(R)']
#       3
# ----> 4 slope,interception,r,std_err = stats.linregress(x,y)
#       5 def fn(x):
#       6     return slope * x + intercept
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\_stats_mstats_common.py in linregress(x, y)
#     110
#     111     n = len(x)
# --> 112     xmean = np.mean(x, None)
#     113     ymean = np.mean(y, None)
#     114
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\core\fromnumeric.py in mean(a, axis, dtype, out, keepdims)
#    3116
#    3117     return _methods._mean(a, axis=axis, dtype=dtype,
# -> 3118                           out=out, **kwargs)
#    3119
#    3120
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\core\_methods.py in _mean(a, axis, dtype, out, keepdims)
# ...
